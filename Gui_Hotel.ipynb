# %%
import tkinter as tk
import pandas as pd
import joblib
from tkinter import messagebox

loaded_model = joblib.load('hotelBehavior.pkl')

# Define a function to apply the model to user inputs and display the result
def predict_cancellation():
    no_of_adults = int(no_of_adults_entry.get())
    no_of_children = int(no_of_children_entry.get())
    no_of_weekend_nights = int(no_of_weekend_nights_entry.get())
    no_of_week_nights = int(no_of_week_nights_entry.get())
    type_of_meal_plan = int(type_of_meal_plan_entry.get())
    required_car_parking_space = int(required_car_parking_space_entry.get())
    room_type_reserved = int(room_type_reserved_entry.get())
    lead_time = int(lead_time_entry.get())
    arrival_year = int(arrival_year_entry.get())
    arrival_month = int(arrival_month_entry.get())
    arrival_date = int(arrival_date_entry.get())
    market_segment_type = int(market_segment_type_entry.get())
    repeated_guest = int(repeated_guest_entry.get())
    no_of_previous_cancellations = int(no_of_previous_cancellations_entry.get())
    no_of_previous_bookings_not_canceled = int(no_of_previous_bookings_not_canceled_entry.get())
    avg_price_per_room = float(avg_price_per_room_entry.get())
    no_of_special_requests = int(no_of_special_requests_entry.get())

    inputs = [[no_of_adults, no_of_children, no_of_weekend_nights, no_of_week_nights, type_of_meal_plan,
               required_car_parking_space, room_type_reserved, lead_time, arrival_year, arrival_month, arrival_date,
               market_segment_type, repeated_guest, no_of_previous_cancellations, no_of_previous_bookings_not_canceled,
               avg_price_per_room, no_of_special_requests]]

    # Get the predicted probability
    prediction = loaded_model.predict(inputs)

    # Display the result to the user
    if prediction == 1:
        result_label.config(text='This reservation would be canceled', bg="red", fg='white')
    else:
        result_label.config(text='This reservation probably wont be canceled', bg="green", fg='white')


# Create the GUI
root = tk.Tk()
root.configure(background='light blue')
root.title('Would this reservation get canceled?')
root.geometry('1000x1000')

# Replace the input() statements with the following code
no_of_adults_label = tk.Label(root, text='Enter the number of adults:', font=('Arial', 12))
no_of_adults_entry = tk.Entry(root, font=('Arial', 12))
no_of_adults_label.grid(row=10, column=0, padx=10, pady=10, sticky=tk.W)
no_of_adults_entry.grid(row=10, column=1, padx=10, pady=10)

no_of_children_label = tk.Label(root, text='Enter the number of children:', font=('Arial', 12))
no_of_children_entry = tk.Entry(root, font=('Arial', 12))
no_of_children_label.grid(row=11, column=0, padx=10, pady=10, sticky=tk.W)
no_of_children_entry.grid(row=11, column=1, padx=10, pady=10)

no_of_weekend_nights_label = tk.Label(root, text='Enter the number of weekend nights:', font=('Arial', 12))
no_of_weekend_nights_entry = tk.Entry(root, font=('Arial', 12))
no_of_weekend_nights_label.grid(row=12, column=0, padx=10, pady=10, sticky=tk.W)
no_of_weekend_nights_entry.grid(row=12, column=1, padx=10, pady=10)

no_of_week_nights_label = tk.Label(root, text='Enter the number of week nights:', font=('Arial', 12))
no_of_week_nights_entry = tk.Entry(root, font=('Arial', 12))
no_of_week_nights_label.grid(row=13, column=0, padx=10, pady=10, sticky=tk.W)
no_of_week_nights_entry.grid(row=13, column=1, padx=10, pady=10)

type_of_meal_plan_label = tk.Label(root, text='Enter the type of meal plan:', font=('Arial', 12))
type_of_meal_plan_entry = tk.Entry(root, font=('Arial', 12))
type_of_meal_plan_label.grid(row=14, column=0, padx=10, pady=10, sticky=tk.W)
type_of_meal_plan_entry.grid(row=14, column=1, padx=10, pady=10)

required_car_parking_space_label = tk.Label(root, text='Enter whether you need a car parking space (Y/N):', font=('Arial', 12))
required_car_parking_space_entry = tk.Entry(root, font=('Arial', 12))
required_car_parking_space_label.grid(row=15, column=0, padx=10, pady=10, sticky=tk.W)
required_car_parking_space_entry.grid(row=15, column=1, padx=10, pady=10)


room_type_reserved_label = tk.Label(root, text='Enter the type of room reserved:', font=('Arial', 12))
room_type_reserved_entry = tk.Entry(root, font=('Arial', 12))
room_type_reserved_label.grid(row=16, column=0, padx=10, pady=10, sticky=tk.W)
room_type_reserved_entry.grid(row=16, column=1, padx=10, pady=10)

lead_time_label = tk.Label(root, text='Enter the lead time:', font=('Arial', 12))
lead_time_entry = tk.Entry(root, font=('Arial', 12))
lead_time_label.grid(row=17, column=0, padx=10, pady=10, sticky=tk.W)
lead_time_entry.grid(row=17, column=1, padx=10, pady=10)

arrival_year_label = tk.Label(root, text='Enter the arrival year:', font=('Arial', 12))
arrival_year_entry = tk.Entry(root, font=('Arial', 12))
arrival_year_label.grid(row=18, column=0, padx=10, pady=10, sticky=tk.W)
arrival_year_entry.grid(row=18, column=1, padx=10, pady=10)

arrival_month_label = tk.Label(root, text='Enter the arrival month:', font=('Arial', 12))
arrival_month_entry = tk.Entry(root, font=('Arial', 12))
arrival_month_label.grid(row=19, column=0, padx=10, pady=10, sticky=tk.W)
arrival_month_entry.grid(row=19, column=1, padx=10, pady=10)

arrival_date_label = tk.Label(root, text='Enter the arrival date:', font=('Arial', 12))
arrival_date_entry = tk.Entry(root, font=('Arial', 12))
arrival_date_label.grid(row=20, column=0, padx=10, pady=10, sticky=tk.W)
arrival_date_entry.grid(row=20, column=1, padx=10, pady=10)

market_segment_type_label = tk.Label(root, text='Enter the market segment type:', font=('Arial', 12))
market_segment_type_entry = tk.Entry(root, font=('Arial', 12))
market_segment_type_label.grid(row=21, column=0, padx=10, pady=10, sticky=tk.W)
market_segment_type_entry.grid(row=21, column=1, padx=10, pady=10)

repeated_guest_label = tk.Label(root, text='Enter whether you are a repeated guest (Y/N):', font=('Arial', 12))
repeated_guest_entry = tk.Entry(root, font=('Arial', 12))
repeated_guest_label.grid(row=22, column=0, padx=10, pady=10, sticky=tk.W)
repeated_guest_entry.grid(row=22, column=1, padx=10, pady=10)

no_of_previous_cancellations_label = tk.Label(root, text='Enter the number of previous cancellations:', font=('Arial', 12))
no_of_previous_cancellations_entry = tk.Entry(root, font=('Arial', 12))
no_of_previous_cancellations_label.grid(row=23, column=0, padx=10, pady=10, sticky=tk.W)
no_of_previous_cancellations_entry.grid(row=23, column=1, padx=10, pady=10)

no_of_previous_bookings_not_canceled_label = tk.Label(root, text='Enter the number of previous bookings not canceled:', font=('Arial', 12))
no_of_previous_bookings_not_canceled_entry = tk.Entry(root, font=('Arial', 12))
no_of_previous_bookings_not_canceled_label.grid(row=24, column=0, padx=10, pady=10, sticky=tk.W)
no_of_previous_bookings_not_canceled_entry.grid(row=24, column=1, padx=10, pady=10)

avg_price_per_room_label = tk.Label(root, text='Enter the average price per room:', font=('Arial', 12))
avg_price_per_room_entry = tk.Entry(root, font=('Arial', 12))
avg_price_per_room_label.grid(row=25, column=0, padx=10, pady=10, sticky=tk.W)
avg_price_per_room_entry.grid(row=25, column=1, padx=10, pady=10)

no_of_special_requests_label = tk.Label(root, text='The no of Special Requests:', font=('Arial', 12))
no_of_special_requests_entry = tk.Entry(root, font=('Arial', 12))
no_of_special_requests_label.grid(row=26, column=0, padx=10, pady=10, sticky=tk.W)
no_of_special_requests_entry.grid(row=26, column=1, padx=10, pady=10)

# Repeat the above code for other input fields...

# Create the classify button
classify_button = tk.Button(root, text='Check', command=predict_cancellation)
classify_button.grid(row=27, column=0, columnspan=2)

# Create the result label
result_label = tk.Label(root, text='')
result_label.grid(row=28, column=0, columnspan=2)

# Run the GUI
root.mainloop()
